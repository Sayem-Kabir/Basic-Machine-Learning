# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('canada_per_capita_income.csv')
df.head()
# Out:
#    year  per_capita_income
# 0  1970        3399.299037
# 1  1971        3768.297935
# 2  1972        4251.175484
# 3  1973        4804.463248
# 4  1974        5576.514583

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']],df.per_capita_income)

# %%
plt.scatter(df.year, df.per_capita_income,color='red',marker='o')
plt.xlabel("Years")
plt.ylabel("Per capita income (USD)")
plt.plot(df.year,reg.predict(df[['year']]),color='b')
plt.show()

# %%
reg.predict([[2020]])
# Out:
# C:\Users\sayem\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
